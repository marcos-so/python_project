# %%
class Leitura:
    def __init__(self, nome:str):
        self.nome = nome

    def __enter__(self):
        print('Hahaha')

    def __exit__(self,a ,b ,c):
        print('saiu')

    def __repr__(self):
        return f'Leitura({self.nome})'

# %%
Leitura('arquivo.txt')
# Out:
# Leitura(arquivo.txt)
